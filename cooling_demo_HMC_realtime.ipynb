# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
arr2 = open("/home/praveen/Downloads/CoMeT-main/hotspot_tool/oldarch/t_thresh_gcc_77.trace",'r').readlines()
length = len(arr2)

# %%
max_core = []
max_mem = []
for i in range(1,length):
    cores = []
    mem = []
    for j in range(4):
        cores.append(float(arr2[i].split()[j]))
    high_c = max(cores)
    for j in range(23, 175):
        if arr2[0][j] not in ('X1', 'X2', 'X3'):
            mem.append(float(arr2[i].split()[j]))
    high_m = max(mem)
    max_core.append(high_c)
    max_mem.append(high_m)
xaxis = np.arange(1, length)
plt.plot(xaxis, max_core, label = "maximum core temperature")
# plt.plot(xaxis, max_mem)   
plt.grid()
plt.ylabel("temperature in Celsius")
plt.xlabel("time in milliseconds")
plt.legend()
plt.yticks(np.arange(66,83, 1))
# Out:
# ([<matplotlib.axis.YTick at 0x7fe8114053d0>,
#   <matplotlib.axis.YTick at 0x7fe8116b9d30>,
#   <matplotlib.axis.YTick at 0x7fe811696e50>,
#   <matplotlib.axis.YTick at 0x7fe8113d58e0>,
#   <matplotlib.axis.YTick at 0x7fe8113d5d90>,
#   <matplotlib.axis.YTick at 0x7fe8113dcb20>,
#   <matplotlib.axis.YTick at 0x7fe8113e1610>,
#   <matplotlib.axis.YTick at 0x7fe8113e1e80>,
#   <matplotlib.axis.YTick at 0x7fe8113e7bb0>,
#   <matplotlib.axis.YTick at 0x7fe8113d5d30>,
#   <matplotlib.axis.YTick at 0x7fe8113ee4f0>,
#   <matplotlib.axis.YTick at 0x7fe8113eefa0>,
#   <matplotlib.axis.YTick at 0x7fe8113f3a90>,
#   <matplotlib.axis.YTick at 0x7fe811379580>,
#   <matplotlib.axis.YTick at 0x7fe8113e73d0>,
#   <matplotlib.axis.YTick at 0x7fe811379cd0>,
#   <matplotlib.axis.YTick at 0x7fe8113817c0>],
#  [Text(0, 66, '66'),
#   Text(0, 67, '67'),
#   Text(0, 68, '68'),
#   Text(0, 69, '69'),
#   Text(0, 70, '70'),
#   Text(0, 71, '71'),
#   Text(0, 72, '72'),
#   Text(0, 73, '73'),
#   Text(0, 74, '74'),
#   Text(0, 75, '75'),
#   Text(0, 76, '76'),
#   Text(0, 77, '77'),
#   Text(0, 78, '78'),
#   Text(0, 79, '79'),
#   Text(0, 80, '80'),
#   Text(0, 81, '81'),
#   Text(0, 82, '82')])

# %%
plt.plot(xaxis, max_mem, label = "maximum bank temperature")   
plt.grid()
plt.ylabel("temperature in Celsius")
plt.xlabel("time in milliseconds")
plt.yticks(np.arange(66,83, 1))
plt.legend()
